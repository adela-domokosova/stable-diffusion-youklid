# %% [markdown]
# <a href="https://colab.research.google.com/github/adela-domokosova/stable-diffusion-youklid/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf diffusers
# !git clone https://github.com/huggingface/diffusers
# !cd diffusers && pip install .
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 98901, done.
# remote: Counting objects: 100% (978/978), done.
# remote: Compressing objects: 100% (461/461), done.
# remote: Total 98901 (delta 803), reused 517 (delta 517), pack-reused 97923 (from 4)
# Receiving objects: 100% (98901/98901), 74.02 MiB | 16.19 MiB/s, done.
# Resolving deltas: 100% (72868/72868), done.
# Processing /content/diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.35.0.dev0-py3-none-any.whl size=4030015 sha256=fdc5db1d1ba0dd1bee146cec60e9e51bf9d2da6414961f9e1f34c7187c45d952
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e2uewbs0/wheels/30/15/ca/ab6e88c89d6ba7047b3f155894c6c346e7cf06067fd132ae62
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.34.0
# ...

# %%
# !cd /content/diffusers/examples/dreambooth && pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# login HF

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# Load training data

# %%
import shutil
from google.colab import files
import os

# If uploading directly to Colab:
uploaded = files.upload()
os.makedirs('formated_commented_png_512', exist_ok=True)
for fname in uploaded.keys():
    shutil.move(fname, f'formated_commented_png_512/{fname}')

# %% [markdown]
# Prepare training data

# %%
import os
import json
from PIL import Image

DATA_DIR = 'formated_commented_png_512'


def main():
    images = [f for f in os.listdir(DATA_DIR) if f.lower().endswith('.png')]
    missing_txt = []
    bad_json = []
    all_data = []

    for img_name in images:
        base = os.path.splitext(img_name)[0]
        txt_path = os.path.join(DATA_DIR, base + '.json')
        img_path = os.path.join(DATA_DIR, img_name)
        if not os.path.exists(txt_path):
            missing_txt.append(img_name)
            continue
        try:
            with open(txt_path, 'r', encoding='utf-8') as f:
                desc_json = json.load(f)
            # Try to get a caption/description field, fallback to the whole JSON as string
            caption = desc_json.get('caption') or desc_json.get('description') or str(desc_json)
        except Exception as e:
            bad_json.append((img_name, str(e)))
            continue
        try:
            with Image.open(img_path) as im:
                if im.size != (512, 512):
                    print(f'Warning: {img_name} is not 512x512, it is {im.size}')
        except Exception as e:
            print(f'Error opening image {img_name}: {e}')
            continue
        all_data.append({'image': img_path, 'caption': caption})

    print(f'Total images found: {len(images)}')
    print(f'Images with valid captions: {len(all_data)}')
    if missing_txt:
        print(f'Images missing .txt files: {missing_txt}')
    if bad_json:
        print(f'Images with invalid JSON: {bad_json}')
    print('Sample entry:', all_data[0] if all_data else 'No valid data found')

    # Optionally, save a dataset manifest for training
    with open('dataset_manifest.jsonl', 'w', encoding='utf-8') as out:
        for entry in all_data:
            out.write(json.dumps(entry, ensure_ascii=False) + '\n')
    print('Wrote dataset_manifest.jsonl')

if __name__ == '__main__':
    main()

# %%
image = pipeline("An image of a squirrel in Picasso style").images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image.save("image_of_squirrel_painting.png")
