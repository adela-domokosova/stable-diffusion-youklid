# %% [markdown]
# <a href="https://colab.research.google.com/github/adela-domokosova/stable-diffusion-youklid/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf diffusers
# !git clone https://github.com/huggingface/diffusers
# !cd diffusers && pip install .
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 100045, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 100045 (delta 24), reused 23 (delta 8), pack-reused 99985 (from 1)
# Receiving objects: 100% (100045/100045), 74.42 MiB | 35.02 MiB/s, done.
# Resolving deltas: 100% (73938/73938), done.
# Processing /content/diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.35.0.dev0-py3-none-any.whl size=4050972 sha256=e701294ee79299050ef4ffd9bda594cfb13f8dc7a0998cf766aa25d6ecb4302f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0f5l30e0/wheels/30/15/ca/ab6e88c89d6ba7047b3f155894c6c346e7cf06067fd132ae62
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.34.0
#     Uninstalling diffusers-0.34.0:
# ...

# %%
# !cd /content/diffusers/examples/dreambooth && pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall peft
# Out:
# Found existing installation: peft 0.7.0
# Uninstalling peft-0.7.0:
#   Would remove:
#     /usr/local/lib/python3.11/dist-packages/peft-0.7.0.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/peft/*
# Proceed (Y/n)? y
#   Successfully uninstalled peft-0.7.0

# %%
# !pip install peft==0.16.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 9.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# login HF

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# Load training data

# %%
import shutil
from google.colab import files
import os

# If uploading directly to Colab:
uploaded = files.upload()
os.makedirs('formated_commented_png_512', exist_ok=True)
for fname in uploaded.keys():
    shutil.move(fname, f'formated_commented_png_512/{fname}')
# Out:
#      <input type="file" id="files-8a7e8a8d-fa77-4258-a77c-b19ca696ffa5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a7e8a8d-fa77-4258-a77c-b19ca696ffa5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Prepare training data

# %%
# !mkdir /content/output

# %%
from accelerate.utils import write_basic_config

write_basic_config()
# Out:
# PosixPath('/root/.cache/huggingface/accelerate/default_config.yaml')

# %%
# !pip uninstall -y xformers
# Out:
# WARNING: Skipping xformers as it is not installed.

# %%
# !accelerate launch /content/diffusers/examples/dreambooth/train_dreambooth.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-2-1" \
  --instance_data_dir="/content/formated_commented_png_512" \
  --output_dir="/content/sd-dreambooth-output" \
  --instance_prompt="sks illustration" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --checkpointing_steps=100 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=700 \
  --mixed_precision="fp16"
# Out:
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-08-02 15:54:34.068539: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-02 15:54:34.083845: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754150074.101835    2224 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# evaluation of checkpoints

# %%
import torch, os
from diffusers import StableDiffusionPipeline, UNet2DConditionModel

base_model = "stabilityai/stable-diffusion-2-1"
ckpt_dir   = "/content/sd-dreambooth-output/checkpoint-700"  # pick a step

# 1) Load the base pipeline
pipe = StableDiffusionPipeline.from_pretrained(base_model, torch_dtype=torch.float16).to("cuda")
if hasattr(pipe, "enable_sdpa"): pipe.enable_sdpa()
pipe.enable_vae_slicing(); pipe.enable_vae_tiling()
pipe.safety_checker = None

# 2) Load UNet weights from the checkpoint and plug them into the pipeline
unet = UNet2DConditionModel.from_pretrained(ckpt_dir, subfolder="unet", torch_dtype=torch.float16).to("cuda")
pipe.unet = unet

# 3) Generate
img = pipe(
    "a single person, solo, one figure, centered, plain background, sks illustration",
    negative_prompt="two people, crowd, busy background, extra limbs, extra fingers, malformed hands, deformed",
    num_inference_steps=25, guidance_scale=6.0, width=512, height=512
).images[0]
img.save("/content/val_700.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
# !mkdir /content/drive/MyDrive/modelv
! cp -r /content/sd-dreambooth-output/model_index.json /content/drive/MyDrive/modelv
! cp -r /content/sd-dreambooth-output/vae /content/drive/MyDrive/modelv
! cp -r /content/sd-dreambooth-output/tokenizer /content/drive/MyDrive/modelv
! cp -r /content/sd-dreambooth-output/scheduler /content/drive/MyDrive/modelv
! cp -r /content/sd-dreambooth-output/unet /content/drive/MyDrive/modelv

! cp -r /content/sd-dreambooth-output/checkpoint-300/unet /content/drive/MyDrive/modelv/unet_300
! cp -r /content/sd-dreambooth-output/checkpoint-400/unet /content/drive/MyDrive/modelv/unet_400
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/modelv’: File exists
